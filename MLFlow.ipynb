# %%
#pip install mlflow
#pip install "protobuf<4.21,>=3.20"
# Out:
# Collecting mlflow
#   Downloading mlflow-3.6.0-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-skinny==3.6.0 (from mlflow)
#   Downloading mlflow_skinny-3.6.0-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.6.0 (from mlflow)
#   Downloading mlflow_tracing-3.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: Flask<4 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow) (2.2.2)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.17.2-py3-none-any.whl.metadata (7.2 kB)
# Collecting cryptography<47,>=43.0.0 (from mlflow)
#   Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting huey<3,>=2.5.0 (from mlflow)
#   Downloading huey-2.5.4-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: matplotlib<4 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow) (3.7.1)
# Requirement already satisfied: numpy<3 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow) (1.24.4)
# Requirement already satisfied: pandas<3 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow) (1.5.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow) (11.0.0)
# Requirement already satisfied: scikit-learn<2 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow) (1.7.1)
# Requirement already satisfied: scipy<2 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow) (1.4.39)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow-skinny==3.6.0->mlflow) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow-skinny==3.6.0->mlflow) (8.0.4)
# Requirement already satisfied: cloudpickle<4 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow-skinny==3.6.0->mlflow) (2.2.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.6.0->mlflow)
#   Downloading databricks_sdk-0.73.0-py3-none-any.whl.metadata (40 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.6.0->mlflow)
#   Downloading fastapi-0.123.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow-skinny==3.6.0->mlflow) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.0.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.6.0->mlflow)
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.6.0->mlflow)
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.6.0->mlflow)
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow-skinny==3.6.0->mlflow) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow-skinny==3.6.0->mlflow) (4.25.6)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow-skinny==3.6.0->mlflow) (2.9.1)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.1.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.0)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow-skinny==3.6.0->mlflow) (2.31.0)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.6.0->mlflow)
#   Downloading sqlparse-0.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from mlflow-skinny==3.6.0->mlflow) (4.11.0)
# Collecting uvicorn<1 (from mlflow-skinny==3.6.0->mlflow)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions<5,>=4.0.0 (from mlflow-skinny==3.6.0->mlflow)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting cffi>=2.0.0 (from cryptography<47,>=43.0.0->mlflow)
#   Downloading cffi-2.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Requirement already satisfied: google-auth~=2.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (2.29.0)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.6.0->mlflow)
#   Downloading protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from docker<8,>=4.0.0->mlflow) (1.26.16)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.6.0->mlflow)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.6.0->mlflow)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: Werkzeug>=2.2.2 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from Flask<4->mlflow) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from Flask<4->mlflow) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from Flask<4->mlflow) (2.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (4.9)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from graphene<4->mlflow) (2.8.2)
# Requirement already satisfied: zipp>=0.5 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.6.0->mlflow) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow) (3.0.9)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.6.0->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from pandas<3->mlflow) (2022.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (2.23.3)
# Requirement already satisfied: six>=1.5 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (2023.7.22)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (0.4.8)
# Requirement already satisfied: joblib>=1.2.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Collecting anyio<5,>=3.6.2 (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow)
#   Downloading anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: h11>=0.8 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from uvicorn<1->mlflow-skinny==3.6.0->mlflow) (0.14.0)
# Requirement already satisfied: pycparser in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/debajyotidas/anaconda3_arm/anaconda3/lib/python3.11/site-packages (from Jinja2>=3.0->Flask<4->mlflow) (2.1.1)
# Downloading mlflow-3.6.0-py3-none-any.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 29.8 MB/s  0:00:00 eta 0:00:01
# Downloading mlflow_skinny-3.6.0-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 45.4 MB/s  0:00:00
# Downloading mlflow_tracing-3.6.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.8 MB/s  0:00:00
# Downloading alembic-1.17.2-py3-none-any.whl (248 kB)
# Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 37.7 MB/s  0:00:00
# Downloading databricks_sdk-0.73.0-py3-none-any.whl (753 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.9/753.9 kB 34.5 MB/s  0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.123.4-py3-none-any.whl (111 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading huey-2.5.4-py3-none-any.whl (76 kB)
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Downloading protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Downloading sqlparse-0.5.4-py3-none-any.whl (45 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading cffi-2.0.0-cp311-cp311-macosx_11_0_arm64.whl (180 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Installing collected packages: huey, uvicorn, typing-extensions, sqlparse, protobuf, Mako, gunicorn, graphql-core, cffi, annotated-doc, opentelemetry-proto, opentelemetry-api, graphql-relay, docker, cryptography, anyio, alembic, starlette, opentelemetry-semantic-conventions, graphene, Flask-CORS, databricks-sdk, opentelemetry-sdk, fastapi, mlflow-tracing, mlflow-skinny, mlflow
#   Attempting uninstall: typing-extensions━━━━━━━━━━━━━━━━━━━━━━━━━  1/27 [uvicorn]
#     Found existing installation: typing_extensions 4.11.0━━━━━  1/27 [uvicorn]
#     Uninstalling typing_extensions-4.11.0:━━━━━━━━━━━━━━━━━━━━  1/27 [uvicorn]
#       Successfully uninstalled typing_extensions-4.11.0━━━━━━━━━━━  2/27 [typing-extensions]
#   Attempting uninstall: protobuf━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/27 [typing-extensions]
#     Found existing installation: protobuf 4.25.6━━━━━━━━━━━━━━  2/27 [typing-extensions]
#     Uninstalling protobuf-4.25.6:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/27 [typing-extensions]
#       Successfully uninstalled protobuf-4.25.6━━━━━━━━━━━━━━━━  2/27 [typing-extensions]
#   Attempting uninstall: cffi━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/27 [graphql-core]]
#     Found existing installation: cffi 1.15.1━━━━━━━━━━━━━━━━━━  7/27 [graphql-core]
#     Uninstalling cffi-1.15.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/27 [graphql-core]
#       Successfully uninstalled cffi-1.15.1━━━━━━━━━━━━━━━━━━━━━━━━  8/27 [cffi]ore]
#   Attempting uninstall: cryptography╺━━━━━━━━━━━━━━━━━━━━ 13/27 [docker]
#     Found existing installation: cryptography 41.0.2━━━━━━━━━━ 13/27 [docker]
#     Uninstalling cryptography-41.0.2:━━━━━━━━━━━━━━━━━━━━ 13/27 [docker]
#       Successfully uninstalled cryptography-41.0.2━━━━━━━━━━━━ 13/27 [docker]
#   Attempting uninstall: anyio╸━━━━━━━━━━━━━━━━━━━ 14/27 [cryptography]
#     Found existing installation: anyio 3.5.0━━━━━━━━━━━━━━━━━━ 14/27 [cryptography]
#     Uninstalling anyio-3.5.0:━╺━━━━━━━━━━━━━━━━━ 15/27 [anyio]hy]
#       Successfully uninstalled anyio-3.5.090m━━━━━━━━━━━━━━━━━ 15/27 [anyio]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27/27 [mlflow]26/27 [mlflow]skinny]]dk]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 1.23.4 requires anyio<4,>=3.1.0, but you have anyio 4.12.0 which is incompatible.
# msal 1.31.0 requires cryptography<46,>=2.5, but you have cryptography 46.0.3 which is incompatible.
# tensorflow-macos 2.15.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 6.33.1 which is incompatible.
# googleapis-common-protos 1.65.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.20.2, but you have protobuf 6.33.1 which is incompatible.
# grpcio-status 1.66.1 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.1 which is incompatible.
# proto-plus 1.24.0 requires protobuf<6.0.0dev,>=3.19.0, but you have protobuf 6.33.1 which is incompatible.
# google-cloud-resource-manager 1.12.5 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.1 which is incompatible.
# google-api-core 2.19.2 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5, but you have protobuf 6.33.1 which is incompatible.
# pyopenssl 23.2.0 requires cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0, but you have cryptography 46.0.3 which is incompatible.
# google-cloud-aiplatform 1.65.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.1 which is incompatible.
# langchain-community 0.3.20 requires numpy<3,>=1.26.2, but you have numpy 1.24.4 which is incompatible.
# grpc-google-iam-v1 0.13.1 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.1 which is incompatible.
# streamlit 1.44.1 requires protobuf<6,>=3.20, but you have protobuf 6.33.1 which is incompatible.
# Successfully installed Flask-CORS-6.0.1 Mako-1.3.10 alembic-1.17.2 annotated-doc-0.0.4 anyio-4.12.0 cffi-2.0.0 cryptography-46.0.3 databricks-sdk-0.73.0 docker-7.1.0 fastapi-0.123.4 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 gunicorn-23.0.0 huey-2.5.4 mlflow-3.6.0 mlflow-skinny-3.6.0 mlflow-tracing-3.6.0 opentelemetry-api-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 protobuf-6.33.1 sqlparse-0.5.4 starlette-0.50.0 typing-extensions-4.15.0 uvicorn-0.38.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import mlflow
mlflow.__version__
# Out:
# '3.6.0'

# %%
# Run either of the 2 below commands in terminal to start MLFLow tracking
# mlflow ui --backend-store-uri sqlite:///mlflow.db --port 5000                         # Start the UI by pointing to the SQLite file
# mlflow server --backend-store-uri sqlite:///mlflow.db --port 5000                     # Start the MLflow server to start tracking
# mlflow server --backend-store-uri sqlite:///mlflow.db --host 0.0.0.0 --port 5000      # Start the MLflow server to start tracking and listen on all network interfaces. including localhost, by explicitly binding MLflow to all interfaces.

# %%
import mlflow

# Set the tracking URI to a local SQLite database file or a remote MLflow server
# mlflow.set_tracking_uri("sqlite:///mlflow.db")    # Point directly to the SQLite file
mlflow.set_tracking_uri("http://127.0.0.1:5000")    # Point to the remote MLflow server via REST API
mlflow.set_experiment("my-experiment")

# %% [markdown]
# In case we are starting the UI by pointing directly to the SQLite file, the new experiment will only show up after logging a run, and even then they may look like they’re under default. This is because the UI isn’t a full tracking server — it’s just a static viewer and the experiment wasn’t created via the server API. In this mode, MLflow happily logs your run, but the UI only shows experiments that were created through the server API. Since we're bypassing the server, the UI doesn’t know about my-experiment and lumps the run under default.
#
# On the other hand, setting the tracking UI to localhost (or in this case: 127.0.0.1) makes the new experiment immediately visible in the UI. This is because setting the tracking to localhost makes the notebook talk to the server via REST API, and the server writes into the DB. This is the “production-like” setup, and the UI at http://localhost:5000 shows experiments created through the server.
#
# In quickstart mode (sqlite:///mlflow.db), set_experiment only registers in the DB when you log a run (and even then they may look like they’re under default) while in remote mode (http://localhost:5000), set_experiment immediately registers via the server API, so the UI shows it right away. We can start the UI/server in either mlflow ui for local DB mode, or mlflow server for remote mode, but either way only setting the tracking via localhost gives reliable viewership.
#
# Overall, its best to combine the below modes:
#
# *mlflow server --backend-store-uri sqlite:///mlflow.db --port 5000*
#
# *mlflow.set_tracking_uri("http://locahost:5000")*

# %%
# Print connection information
print(f"MLflow Tracking URI: {mlflow.get_tracking_uri()}")
print(f"Active Experiment: {mlflow.get_experiment_by_name('my-experiment')}")

# Test logging
with mlflow.start_run():
    mlflow.log_param("test_param", "test_value")
    mlflow.log_metric("test_metric", 0.85)     
    print("✓ Successfully connected to MLflow!")
